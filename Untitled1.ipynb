# %%
# %pylab inline
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s1r = pd.read_csv("source_1_residuals.csv",header=None)
s2r = pd.read_csv("source_2_residuals.csv",header=None)
s2data = pd.read_csv("source_2_data.csv",header=None)

# %%
plt.scatter(s1r[0], s1r[1])
plt.figure()
plt.scatter(s2r[0], s2r[1])
plt.figure()
plt.scatter(s2data[0], s2data[1])
